# %%
# Get Onboard Client provided by RTEMHackathon
import json
from onboard.client import RtemClient
# Access API Key securely using config.ini file
import configparser
from pprint import pprint
import pandas as pd

# %%
# Load API Key using configparser
config = configparser.ConfigParser()
config.read('config.ini')
api_key = config['DEFAULT']['API_KEY']

# %%
# Initialise Onboard Client
client = RtemClient(api_key=api_key)

# %%
client.whoami()
# Out:
# {'result': 'ok',
#  'apiKeyInHeader': True,
#  'apiKeyScopes': ['buildings:read', 'general', 'auth'],
#  'apiVersion': '2022-04-14',
#  'userInfo': {'token': None,
#   'name': 'Daniel',
#   'full_name': 'Daniel Lawson',
#   'username': 'dan',
#   'palette': {'primary': {'main': '#3b5998'},
#    'secondary': {'main': '#ffffff'}},
#   'org_short_name': 'RTEM Submission',
#   'org_id': 5,
#   'logo_url': '',
#   'mfa_required': True},
#  'authLevel': 4}

# %%
all_buildings = client.get_all_buildings()

# %%
client.get_all_units()
# Out:
# [{'id': 23,
#   'name_long': 'Unknown',
#   'name_abbr': '?',
#   'data_type': 'None',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': None,
#   'unit_type': None},
#  {'id': 21,
#   'name_long': 'Enable',
#   'name_abbr': 'Enable',
#   'data_type': 'Binary',
#   'raw_encoding': {'0': ['disable'], '1': ['enable']},
#   'display_encoding': {'0': 'Disable', '1': 'Enable'},
#   'qudt': None,
#   'unit_type': None},
#  {'id': 22,
#   'name_long': 'Heat/Cool/Off',
#   'name_abbr': 'H/C/O',
#   'data_type': 'Enum',
#   'raw_encoding': {'0': ['off'], '1': ['heat'], '2': ['cool']},
#   'display_encoding': {'0': 'Off', '1': 'Heat', '2': 'Off'},
#   'qudt': None,
#   'unit_type': None},
#  {'id': 31,
#   'name_long': 'Ordinal Value',
#   'name_abbr': 'Ordinal',
#   'data_type': 'Ordinal',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': None,
#   'unit_type': None},
#  {'id': 34,
#   'name_long': 'Ampere',
#   'name_abbr': 'A',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/A',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/ElectricCurrent'},
#  {'id': 15,
#   'name_long': 'British Thermal Unit/hour',
#   'name_abbr': 'BTU/hr',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/BTU_IT-PER-HR',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Power'},
#  {'id': 28,
#   'name_long': 'BTUs/pound of air',
#   'name_abbr': 'BTU/lb',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/BTU_IT-PER-LB',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/SpecificEnergy'},
#  {'id': 27,
#   'name_long': 'Cubic Feet',
#   'name_abbr': 'ft3',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/FT3',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Volume'},
#  {'id': 7,
#   'name_long': 'Cubic Foot per Minute',
#   'name_abbr': 'cfm',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/FT3-PER-MIN',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/VolumePerUnitTime'},
#  {'id': 1,
#   'name_long': 'Degrees Celsius',
#   'name_abbr': 'C',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/DEG_C',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Temperature'},
#  {'id': 2,
#   'name_long': 'Degrees Fahrenheit',
#   'name_abbr': 'F',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/DEG_F',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Temperature'},
#  {'id': 32,
#   'name_long': 'Floor',
#   'name_abbr': 'Floor',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/UNITLESS',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Dimensionless'},
#  {'id': 35,
#   'name_long': 'Hertz',
#   'name_abbr': 'Hz',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/HZ',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Frequency'},
#  {'id': 42,
#   'name_long': 'Hours',
#   'name_abbr': 'hours',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/HR',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Time'},
#  {'id': 4,
#   'name_long': 'Inches Water Column',
#   'name_abbr': 'in W.C.',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/IN_AQ',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/ForcePerArea'},
#  {'id': 41,
#   'name_long': 'Kilo Volt amp reactive hours',
#   'name_abbr': 'kVARh',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/KiloV-A_Reactive-HR',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Energy'},
#  {'id': 26,
#   'name_long': 'Kilovolt Amperes',
#   'name_abbr': 'kVA',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/KiloV-A',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/ApparentPower'},
#  {'id': 25,
#   'name_long': 'Kilovolt Amperes Reactive',
#   'name_abbr': 'kVAR',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/KiloV-A_Reactive',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/ReactivePower'},
#  {'id': 16,
#   'name_long': 'Kilowatt Hours',
#   'name_abbr': 'kWh',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/KiloW-HR',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Energy'},
#  {'id': 17,
#   'name_long': 'Kilowatts',
#   'name_abbr': 'kW',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/KiloW',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Power'},
#  {'id': 12,
#   'name_long': 'Milliampere',
#   'name_abbr': 'mA',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/MilliA',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/ElectricCurrent'},
#  {'id': 43,
#   'name_long': 'Minutes',
#   'name_abbr': 'min',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/MIN',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Time'},
#  {'id': 10,
#   'name_long': 'Parts per Million',
#   'name_abbr': 'ppm',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/PPM',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/DimensionlessRatio'},
#  {'id': 3,
#   'name_long': 'Percent',
#   'name_abbr': '%',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/PERCENT',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/DimensionlessRatio'},
#  {'id': 9,
#   'name_long': 'Pounds per Hour',
#   'name_abbr': 'lb/hr',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/LB-PER-HR',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/MassPerTime'},
#  {'id': 5,
#   'name_long': 'Pounds per Square Inch',
#   'name_abbr': 'psi',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/LB_F-PER-IN2',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/ForcePerArea'},
#  {'id': 6,
#   'name_long': 'Pounds per Square Inch, Gauge',
#   'name_abbr': 'psig',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/LB_F-PER-IN2',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/ForcePerArea'},
#  {'id': 38,
#   'name_long': 'Power Factor',
#   'name_abbr': 'pf',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/UNITLESS',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Dimensionless'},
#  {'id': 14,
#   'name_long': 'British Thermal Unit',
#   'name_abbr': 'BTU',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/BTU_IT',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Energy'},
#  {'id': 8,
#   'name_long': 'Gallons per Minute',
#   'name_abbr': 'gpm',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/GAL_UK-PER-MIN',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/VolumePerUnitTime'},
#  {'id': 18,
#   'name_long': 'Occupancy',
#   'name_abbr': 'Occ',
#   'data_type': 'Binary',
#   'raw_encoding': {'0': ['unoccupied',
#     'off',
#     'inactive',
#     'standby',
#     'not set',
#     'bypass',
#     'false'],
#    '1': ['occupied', 'on', 'active', 'true']},
#   'display_encoding': {'0': 'Unoccupied', '1': 'Occupied'},
#   'qudt': None,
#   'unit_type': None},
#  {'id': 19,
#   'name_long': 'Open/Closed',
#   'name_abbr': 'O/C',
#   'data_type': 'Binary',
#   'raw_encoding': {'0': ['off',
#     'stop',
#     'stopped',
#     'close',
#     'closed',
#     'inactive',
#     'false'],
#    '1': ['on', 'start', 'started', 'open', 'active', 'true']},
#   'display_encoding': {'0': 'Close', '1': 'Open'},
#   'qudt': None,
#   'unit_type': None},
#  {'id': 20,
#   'name_long': 'On/Off',
#   'name_abbr': 'On/Off',
#   'data_type': 'Binary',
#   'raw_encoding': {'0': ['off', 'stop', 'stopped', 'inactive', 'false'],
#    '1': ['on', 'start', 'started', 'active', 'true']},
#   'display_encoding': {'0': 'Off', '1': 'On'},
#   'qudt': None,
#   'unit_type': None},
#  {'id': 29,
#   'name_long': 'Revolutions per Minute',
#   'name_abbr': 'rpm',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/REV-PER-MIN',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/AngularVelocity'},
#  {'id': 44,
#   'name_long': 'Seconds',
#   'name_abbr': 'sec',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/SEC',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Time'},
#  {'id': 13,
#   'name_long': 'Stage Number',
#   'name_abbr': 'Stage',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/UNITLESS',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Dimensionless'},
#  {'id': 36,
#   'name_long': 'Thousand Pounds per Hour',
#   'name_abbr': 'K lb/hr',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/KiloLB-PER-HR',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/MassPerTime'},
#  {'id': 33,
#   'name_long': 'Tons of Refrigeration',
#   'name_abbr': 'tons',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/TON_FG',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Power'},
#  {'id': 37,
#   'name_long': 'Volt amp hours',
#   'name_abbr': 'VAh',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/V-A-HR',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Energy'},
#  {'id': 39,
#   'name_long': 'Volt amp reactive hours',
#   'name_abbr': 'VARh',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/V-A_Reactive-HR',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Energy'},
#  {'id': 11,
#   'name_long': 'Volts',
#   'name_abbr': 'V',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/V',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/EnergyPerElectricCharge'},
#  {'id': 40,
#   'name_long': 'Watt hours',
#   'name_abbr': 'Wh',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/W-HR',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Energy'},
#  {'id': 45,
#   'name_long': 'Joule',
#   'name_abbr': 'J',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/J',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Energy'},
#  {'id': 46,
#   'name_long': 'Degrees Kelvin',
#   'name_abbr': 'K',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/K',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Temperature'},
#  {'id': 47,
#   'name_long': 'Kilovolt ampere hours',
#   'name_abbr': 'kVAh',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/KiloV-A-HR',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Energy'},
#  {'id': 48,
#   'name_long': 'Feet per Minute',
#   'name_abbr': 'fpm',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/FT-PER-MIN',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/LinearVelocity'},
#  {'id': 49,
#   'name_long': 'Metres per Second',
#   'name_abbr': 'm/s',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/M-PER-SEC',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/LinearVelocity'},
#  {'id': 50,
#   'name_long': 'kilo Pascal',
#   'name_abbr': 'kPA',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/KiloPA',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/ForcePerArea'},
#  {'id': 51,
#   'name_long': 'Pascal',
#   'name_abbr': 'PA',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/PA',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/ForcePerArea'},
#  {'id': 54,
#   'name_long': 'Cubic Meter',
#   'name_abbr': 'm3',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/M3',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Volume'},
#  {'id': 56,
#   'name_long': 'Kilometer per Hour',
#   'name_abbr': 'km/h',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/KiloM-PER-HR',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/LinearVelocity'},
#  {'id': 57,
#   'name_long': 'Cubic Meter per Second',
#   'name_abbr': 'm3/s',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/M3-PER-SEC',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/VolumePerUnitTime'},
#  {'id': 72,
#   'name_long': 'Miles per Hour',
#   'name_abbr': 'mph',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/MI-PER-HR',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/LinearVelocity'},
#  {'id': 78,
#   'name_long': 'Megawatt Hours',
#   'name_abbr': 'mWh',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/MegaW-HR',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Energy'},
#  {'id': 79,
#   'name_long': 'Newton Meter',
#   'name_abbr': 'Nm',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/N-M',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Torque'},
#  {'id': 80,
#   'name_long': 'Litre per Hour',
#   'name_abbr': 'L/h',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/L-PER-HR',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/VolumePerUnitTime'},
#  {'id': 81,
#   'name_long': 'Kilo Joule',
#   'name_abbr': 'kJ',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/KiloJ',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Energy'},
#  {'id': 61,
#   'name_long': 'Mega Joule',
#   'name_abbr': 'MJ',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/MegaJ',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Energy'},
#  {'id': 62,
#   'name_long': 'Kilojoule per Mole',
#   'name_abbr': 'kJ/mol',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/KiloJ-PER-MOL',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/MolarEnergy'},
#  {'id': 63,
#   'name_long': 'Lux',
#   'name_abbr': 'lx',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/LUX',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/LuminousFluxPerArea'},
#  {'id': 64,
#   'name_long': 'Foot',
#   'name_abbr': 'ft',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/FT',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Length'},
#  {'id': 65,
#   'name_long': 'Meter',
#   'name_abbr': 'm',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/M',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Length'},
#  {'id': 66,
#   'name_long': 'Ohm',
#   'name_abbr': 'ohm',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/OHM',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Resistance'},
#  {'id': 67,
#   'name_long': 'Kiloohm',
#   'name_abbr': 'kOhm',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/KiloOHM',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Resistance'},
#  {'id': 70,
#   'name_long': 'US Therm',
#   'name_abbr': 'thm',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/THM_US',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Energy'},
#  {'id': 71,
#   'name_long': 'Joules per Kilogram',
#   'name_abbr': 'J/kg',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/J-PER-KiloGM',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/SpecificEnergy'},
#  {'id': 58,
#   'name_long': 'Litre Per Second',
#   'name_abbr': 'L/s',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/L-PER-SEC',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/VolumePerUnitTime'},
#  {'id': 73,
#   'name_long': 'Number',
#   'name_abbr': 'num',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/NUM',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Dimensionless'},
#  {'id': 74,
#   'name_long': 'Joule Per Kelvin',
#   'name_abbr': 'J/K',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/J-PER-K',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/HeatCapacity'},
#  {'id': 55,
#   'name_long': 'Litre',
#   'name_abbr': 'L',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/L',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Volume'},
#  {'id': 68,
#   'name_long': 'US Gallon',
#   'name_abbr': 'gal',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/GAL_US',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Volume'},
#  {'id': 75,
#   'name_long': 'Bar',
#   'name_abbr': 'bar',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/BAR',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/ForcePerArea'},
#  {'id': 76,
#   'name_long': 'Watts',
#   'name_abbr': 'w',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/W',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Power'},
#  {'id': 77,
#   'name_long': 'Cubic Meter per Hour',
#   'name_abbr': 'm3/h',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/M3-PER-HR',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/VolumePerUnitTime'},
#  {'id': 82,
#   'name_long': 'Giga Joule',
#   'name_abbr': 'GJ',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/GigaJ',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Energy'},
#  {'id': 83,
#   'name_long': 'Normal Cubic Meter',
#   'name_abbr': 'nm3',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/NM3-NAT-GAS',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Energy'},
#  {'id': 84,
#   'name_long': 'Standard Cubic Meter',
#   'name_abbr': 'SCM',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/SCM-NAT-GAS',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Energy'},
#  {'id': 85,
#   'name_long': 'Standard Cubic Foot',
#   'name_abbr': 'SFt3',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/SFT3-NAT-GAS',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/Energy'},
#  {'id': 86,
#   'name_long': 'Kilojoules per Kilogram',
#   'name_abbr': 'kJ/kg',
#   'data_type': 'Continuous',
#   'raw_encoding': None,
#   'display_encoding': None,
#   'qudt': 'http://qudt.org/vocab/unit/KiloJ-PER-KiloGM',
#   'unit_type': 'http://qudt.org/vocab/quantitykind/SpecificEnergy'}]

# %%
client.get('/unit-preferences').json()
# Out:
# [{'type': 'USER', 'creator_id': 481, 'measurement_id': 1, 'unit_id': 1}, {'type': 'USER', 'creator_id': 481, 'measurement_id': 22, 'unit_id': 55}, {'type': 'USER', 'creator_id': 481, 'measurement_id': 24, 'unit_id': 71}]

# %%
pprint(all_buildings)
# Out:
# [{'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 20,
#   'id': 441,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'Bronx',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '88737',
#   'org_id': 5,
#   'point_count': 1293,
#   'sq_ft': 551143,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 13,
#   'id': 140,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '83483',
#   'org_id': 5,
#   'point_count': 354,
#   'sq_ft': 21869,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 7,
#   'id': 191,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Retail',
#            'floors': '',
#            'geoCity': 'Victor',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '23:00',
#            'm2fstart': '07:30',
#            'org': '',
#            'satend': '23:00',
#            'satstart': '07:30',
#            'sunend': '23:00',
#            'sunstart': '07:30',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '94414',
#   'org_id': 5,
#   'point_count': 19,
#   'sq_ft': 198057,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 4,
#   'id': 231,
#   'image_src': None,
#   'info': {'customerType': '',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '89496',
#   'org_id': 5,
#   'point_count': 51,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 7,
#   'id': 248,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '116742',
#   'org_id': 5,
#   'point_count': 34,
#   'sq_ft': 127000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 2,
#   'id': 249,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Retail',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '90366',
#   'org_id': 5,
#   'point_count': 6,
#   'sq_ft': 120000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 10,
#   'id': 434,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'Brooklyn',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '129666',
#   'org_id': 5,
#   'point_count': 163,
#   'sq_ft': 56090,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 13,
#   'id': 271,
#   'image_src': None,
#   'info': {'customerType': 'College/University',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '23:00:00',
#            'm2fstart': '06:00:00',
#            'org': '',
#            'satend': '23:00:00',
#            'satstart': '06:00:00',
#            'sunend': '23:00:00',
#            'sunstart': '06:00:00',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '80324',
#   'org_id': 5,
#   'point_count': 182,
#   'sq_ft': 32240,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 7,
#   'id': 285,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Retail',
#            'floors': '',
#            'geoCity': 'White Plains',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '23:00',
#            'm2fstart': '07:30',
#            'org': '',
#            'satend': '23:00',
#            'satstart': '07:30',
#            'sunend': '23:00',
#            'sunstart': '07:30',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '94400',
#   'org_id': 5,
#   'point_count': 17,
#   'sq_ft': 198057,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 8,
#   'id': 297,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Retail',
#            'floors': '',
#            'geoCity': 'Watertown',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '23:00',
#            'm2fstart': '07:30',
#            'org': '',
#            'satend': '23:00',
#            'satstart': '07:30',
#            'sunend': '23:00',
#            'sunstart': '07:30',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '94412',
#   'org_id': 5,
#   'point_count': 24,
#   'sq_ft': 198057,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 7,
#   'id': 322,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Retail',
#            'floors': '',
#            'geoCity': 'New Hartford',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '23:00',
#            'm2fstart': '07:30',
#            'org': '',
#            'satend': '23:00',
#            'satstart': '07:30',
#            'sunend': '23:00',
#            'sunstart': '07:30',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '94411',
#   'org_id': 5,
#   'point_count': 19,
#   'sq_ft': 198057,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 2,
#   'id': 317,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '128286',
#   'org_id': 5,
#   'point_count': 38,
#   'sq_ft': 35000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 32,
#   'id': 419,
#   'image_src': None,
#   'info': {'customerType': 'College/University',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '116399',
#   'org_id': 5,
#   'point_count': 354,
#   'sq_ft': 130000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 4,
#   'id': 375,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'BRONX',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '97789',
#   'org_id': 5,
#   'point_count': 159,
#   'sq_ft': 232808,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 205,
#   'id': 470,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '164423',
#   'org_id': 5,
#   'point_count': 1140,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 92,
#   'id': 426,
#   'image_src': None,
#   'info': {'customerType': 'Hospitality',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '76513',
#   'org_id': 5,
#   'point_count': 959,
#   'sq_ft': 80000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 139,
#   'id': 423,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'Queens',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '124540',
#   'org_id': 5,
#   'point_count': 463,
#   'sq_ft': 119710,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 1,
#   'id': 439,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'NYC',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '87722',
#   'org_id': 5,
#   'point_count': 1,
#   'sq_ft': 3000000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 9,
#   'id': 314,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '114460',
#   'org_id': 5,
#   'point_count': 51,
#   'sq_ft': 100000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 2,
#   'id': 467,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'Brooklyn',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '139252',
#   'org_id': 5,
#   'point_count': 41,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 30,
#   'id': 455,
#   'image_src': None,
#   'info': {'customerType': 'Chemicals',
#            'floors': '',
#            'geoCity': 'Brooklyn',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '164994',
#   'org_id': 5,
#   'point_count': 195,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 14,
#   'id': 105,
#   'image_src': None,
#   'info': {'customerType': 'Food/Beverage',
#            'floors': '',
#            'geoCity': 'Kingston',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '79789',
#   'org_id': 5,
#   'point_count': 34,
#   'sq_ft': 56000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 42,
#   'id': 107,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY'},
#   'name': '84869',
#   'org_id': 5,
#   'point_count': 44,
#   'sq_ft': 50000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 2,
#   'id': 445,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '145732',
#   'org_id': 5,
#   'point_count': 36,
#   'sq_ft': 33220,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 39,
#   'id': 488,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '152000',
#   'org_id': 5,
#   'point_count': 107,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 45,
#   'id': 417,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '78797',
#   'org_id': 5,
#   'point_count': 599,
#   'sq_ft': 1898155,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 2,
#   'id': 460,
#   'image_src': None,
#   'info': {'customerType': 'Healthcare',
#            'floors': '',
#            'geoCity': 'Flushing',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '153255',
#   'org_id': 5,
#   'point_count': 2,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 14,
#   'id': 472,
#   'image_src': None,
#   'info': {'customerType': 'College/University',
#            'floors': '',
#            'geoCity': 'Corning',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '130262',
#   'org_id': 5,
#   'point_count': 101,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 26,
#   'id': 442,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'Rye',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '150388',
#   'org_id': 5,
#   'point_count': 69,
#   'sq_ft': 205000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 122,
#   'id': 118,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Retail',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': 'Edison Properties',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '73107',
#   'org_id': 5,
#   'point_count': 258,
#   'sq_ft': 275000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 222,
#   'id': 418,
#   'image_src': None,
#   'info': {},
#   'name': '110897',
#   'org_id': 5,
#   'point_count': 506,
#   'sq_ft': 2800000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 27,
#   'id': 477,
#   'image_src': None,
#   'info': {'customerType': 'Healthcare',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '159950',
#   'org_id': 5,
#   'point_count': 331,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 10,
#   'id': 443,
#   'image_src': None,
#   'info': {'customerType': 'College/University',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '149911',
#   'org_id': 5,
#   'point_count': 119,
#   'sq_ft': 600000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 1,
#   'id': 468,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'Bronxville',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '159109',
#   'org_id': 5,
#   'point_count': 24,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 221,
#   'id': 438,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '116350',
#   'org_id': 5,
#   'point_count': 1111,
#   'sq_ft': 1500000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 48,
#   'id': 478,
#   'image_src': None,
#   'info': {'customerType': 'K-12 School',
#            'floors': '',
#            'geoCity': 'Rochester',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '160783',
#   'org_id': 5,
#   'point_count': 308,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 9,
#   'id': 395,
#   'image_src': None,
#   'info': {'customerType': 'Hospitality',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '85481',
#   'org_id': 5,
#   'point_count': 86,
#   'sq_ft': 171129,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 20,
#   'id': 485,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '133932',
#   'org_id': 5,
#   'point_count': 53,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 19,
#   'id': 450,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '131034',
#   'org_id': 5,
#   'point_count': 329,
#   'sq_ft': 665000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 15,
#   'id': 473,
#   'image_src': None,
#   'info': {'customerType': 'K-12 School',
#            'floors': '',
#            'geoCity': 'Warsaw',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '164864',
#   'org_id': 5,
#   'point_count': 106,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 91,
#   'id': 230,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '111479',
#   'org_id': 5,
#   'point_count': 188,
#   'sq_ft': 1040873,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 11,
#   'id': 127,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'Flushing',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '89089',
#   'org_id': 5,
#   'point_count': 319,
#   'sq_ft': 789079,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 2,
#   'id': 469,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'White Plains',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '144601',
#   'org_id': 5,
#   'point_count': 33,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 3,
#   'id': 100,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '116723',
#   'org_id': 5,
#   'point_count': 8,
#   'sq_ft': 153750,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 189,
#   'id': 452,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '128615',
#   'org_id': 5,
#   'point_count': 867,
#   'sq_ft': 1028336,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 2,
#   'id': 461,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Retail',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '137940',
#   'org_id': 5,
#   'point_count': 38,
#   'sq_ft': 47092,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 85,
#   'id': 489,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '163896',
#   'org_id': 5,
#   'point_count': 113,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 126,
#   'id': 99,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'Brooklyn',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '113413',
#   'org_id': 5,
#   'point_count': 262,
#   'sq_ft': 869066,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 38,
#   'id': 98,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '54',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': '1973'},
#   'name': '68855',
#   'org_id': 5,
#   'point_count': 132,
#   'sq_ft': 2338000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 50,
#   'id': 479,
#   'image_src': None,
#   'info': {'customerType': 'K-12 School',
#            'floors': '',
#            'geoCity': 'Pittsford',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '163716',
#   'org_id': 5,
#   'point_count': 268,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 22,
#   'id': 474,
#   'image_src': None,
#   'info': {'customerType': 'Healthcare',
#            'floors': '',
#            'geoCity': 'lewiston',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '164033',
#   'org_id': 5,
#   'point_count': 197,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 2,
#   'id': 466,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'Long Island City',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '137257',
#   'org_id': 5,
#   'point_count': 38,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 129,
#   'id': 134,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '112620',
#   'org_id': 5,
#   'point_count': 264,
#   'sq_ft': 12000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 3,
#   'id': 131,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Retail',
#            'floors': '',
#            'geoCity': 'Brooklyn',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '128313',
#   'org_id': 5,
#   'point_count': 4,
#   'sq_ft': 205000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 16,
#   'id': 130,
#   'image_src': None,
#   'info': {'customerType': 'K-12 School',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '104698',
#   'org_id': 5,
#   'point_count': 181,
#   'sq_ft': 145000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 342,
#   'id': 420,
#   'image_src': None,
#   'info': {'customerType': 'Healthcare',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '87261',
#   'org_id': 5,
#   'point_count': 6068,
#   'sq_ft': 236000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 2,
#   'id': 136,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'Bronx',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '99315',
#   'org_id': 5,
#   'point_count': 26,
#   'sq_ft': 274096,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 16,
#   'id': 475,
#   'image_src': None,
#   'info': {'customerType': 'College/University',
#            'floors': '',
#            'geoCity': 'Canandaigua',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '158818',
#   'org_id': 5,
#   'point_count': 145,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 2,
#   'id': 373,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '96938',
#   'org_id': 5,
#   'point_count': 10,
#   'sq_ft': 127577,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 3,
#   'id': 176,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Retail',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '90367',
#   'org_id': 5,
#   'point_count': 5,
#   'sq_ft': 150000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 1,
#   'id': 490,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'Brooklyn',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '124556',
#   'org_id': 5,
#   'point_count': 73,
#   'sq_ft': 782298,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 9,
#   'id': 217,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '130079',
#   'org_id': 5,
#   'point_count': 14,
#   'sq_ft': 229154,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 16,
#   'id': 103,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '37',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': 'Jack Resnick & Sons',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': '1969'},
#   'name': '75216',
#   'org_id': 5,
#   'point_count': 37,
#   'sq_ft': 563391,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 2,
#   'id': 421,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '108774',
#   'org_id': 5,
#   'point_count': 30,
#   'sq_ft': 7960,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 3,
#   'id': 476,
#   'image_src': None,
#   'info': {'customerType': 'Healthcare',
#            'floors': '',
#            'geoCity': 'Woodside',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '122677',
#   'org_id': 5,
#   'point_count': 3,
#   'sq_ft': 110000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 2,
#   'id': 462,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'Bronx',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '144540',
#   'org_id': 5,
#   'point_count': 45,
#   'sq_ft': 76800,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 7,
#   'id': 142,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '54',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': 'Hines',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': '1972'},
#   'name': '82119',
#   'org_id': 5,
#   'point_count': 36,
#   'sq_ft': 2400000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 16,
#   'id': 422,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'Bronx',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '114249',
#   'org_id': 5,
#   'point_count': 210,
#   'sq_ft': 352360,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 35,
#   'id': 503,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '145813',
#   'org_id': 5,
#   'point_count': 157,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 13,
#   'id': 385,
#   'image_src': None,
#   'info': {'customerType': 'Healthcare',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '92344',
#   'org_id': 5,
#   'point_count': 72,
#   'sq_ft': 180000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 43,
#   'id': 471,
#   'image_src': None,
#   'info': {'customerType': 'Healthcare',
#            'floors': '',
#            'geoCity': 'Rochester',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '136558',
#   'org_id': 5,
#   'point_count': 311,
#   'sq_ft': None,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
# ...
#            'sunstart': '06:30:00',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '96580',
#   'org_id': 5,
#   'point_count': 713,
#   'sq_ft': 259000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 24,
#   'id': 389,
#   'image_src': None,
#   'info': {'customerType': 'Healthcare',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'New York',
#            'm2fend': '00:00',
#            'm2fstart': '00:00',
#            'org': 'NYU Langone',
#            'satend': '00:00',
#            'satstart': '00:00',
#            'sunend': '00:00',
#            'sunstart': '00:00',
#            'weatherRef': '',
#            'yearBuilt': '1979'},
#   'name': '68985',
#   'org_id': 5,
#   'point_count': 384,
#   'sq_ft': 338424,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 5,
#   'id': 390,
#   'image_src': None,
#   'info': {'customerType': 'Food/Beverage',
#            'floors': '',
#            'geoCity': 'Bedford Hills',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '114399',
#   'org_id': 5,
#   'point_count': 5,
#   'sq_ft': 8500,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 35,
#   'id': 391,
#   'image_src': None,
#   'info': {'customerType': 'Healthcare',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '123698',
#   'org_id': 5,
#   'point_count': 245,
#   'sq_ft': 350000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 6,
#   'id': 392,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '127525',
#   'org_id': 5,
#   'point_count': 14,
#   'sq_ft': 399613,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 59,
#   'id': 394,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '18:00:00',
#            'm2fstart': '06:00:00',
#            'org': '',
#            'satend': '18:00:00',
#            'satstart': '06:00:00',
#            'sunend': '18:00:00',
#            'sunstart': '06:00:00',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '80880',
#   'org_id': 5,
#   'point_count': 386,
#   'sq_ft': 725000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 5,
#   'id': 393,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '145147',
#   'org_id': 5,
#   'point_count': 12,
#   'sq_ft': 1100000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 84,
#   'id': 384,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '111478',
#   'org_id': 5,
#   'point_count': 168,
#   'sq_ft': 1040873,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 39,
#   'id': 123,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Retail',
#            'floors': '9',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '82176',
#   'org_id': 5,
#   'point_count': 45,
#   'sq_ft': 330000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 8,
#   'id': 154,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '90200',
#   'org_id': 5,
#   'point_count': 26,
#   'sq_ft': 357297,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 9,
#   'id': 155,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Retail',
#            'floors': '',
#            'geoCity': 'Troy',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '108238',
#   'org_id': 5,
#   'point_count': 24,
#   'sq_ft': 144000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 13,
#   'id': 157,
#   'image_src': None,
#   'info': {'customerType': 'Food/Beverage',
#            'floors': '',
#            'geoCity': 'Syracuse',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '79791',
#   'org_id': 5,
#   'point_count': 35,
#   'sq_ft': 56000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 5,
#   'id': 158,
#   'image_src': None,
#   'info': {'customerType': 'Food/Beverage',
#            'floors': '',
#            'geoCity': 'Tarrytown',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '114403',
#   'org_id': 5,
#   'point_count': 5,
#   'sq_ft': 9000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 7,
#   'id': 166,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Retail',
#            'floors': '',
#            'geoCity': 'Batavia',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '23:00',
#            'm2fstart': '07:30',
#            'org': '',
#            'satend': '23:00',
#            'satstart': '07:30',
#            'sunend': '23:00',
#            'sunstart': '07:30',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '94423',
#   'org_id': 5,
#   'point_count': 19,
#   'sq_ft': 198057,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 3,
#   'id': 184,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'Manhattan',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '108764',
#   'org_id': 5,
#   'point_count': 34,
#   'sq_ft': 52782,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 4,
#   'id': 214,
#   'image_src': None,
#   'info': {'customerType': 'Multifamily',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '97593',
#   'org_id': 5,
#   'point_count': 46,
#   'sq_ft': 12000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 11,
#   'id': 239,
#   'image_src': None,
#   'info': {'customerType': 'K-12 School',
#            'floors': '',
#            'geoCity': 'Bronx',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '86468',
#   'org_id': 5,
#   'point_count': 24,
#   'sq_ft': 450000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 8,
#   'id': 260,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Retail',
#            'floors': '',
#            'geoCity': 'Rome',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '108227',
#   'org_id': 5,
#   'point_count': 34,
#   'sq_ft': 144000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 36,
#   'id': 316,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Retail',
#            'floors': '',
#            'geoCity': 'Blasdell',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '108232',
#   'org_id': 5,
#   'point_count': 59,
#   'sq_ft': 144000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 7,
#   'id': 353,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Retail',
#            'floors': '',
#            'geoCity': 'Henrietta',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '23:00',
#            'm2fstart': '07:30',
#            'org': '',
#            'satend': '23:00',
#            'satstart': '07:30',
#            'sunend': '23:00',
#            'sunstart': '07:30',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '94413',
#   'org_id': 5,
#   'point_count': 19,
#   'sq_ft': 198057,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 5,
#   'id': 370,
#   'image_src': None,
#   'info': {'customerType': 'Hospitality',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '95457',
#   'org_id': 5,
#   'point_count': 22,
#   'sq_ft': 421316,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 11,
#   'id': 383,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '4',
#            'geoCity': 'Purchase',
#            'geoCountry': 'US',
#            'geoState': 'New York',
#            'm2fend': '20:00:00',
#            'm2fstart': '04:00:00',
#            'org': 'Simone Property Dev',
#            'yearBuilt': '1971'},
#   'name': '79528',
#   'org_id': 5,
#   'point_count': 362,
#   'sq_ft': 75000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 26,
#   'id': 398,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '109188',
#   'org_id': 5,
#   'point_count': 295,
#   'sq_ft': 860000,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'},
#  {'address': None,
#   'bms_manufacturer': None,
#   'bms_product_name': None,
#   'bms_version': None,
#   'equip_count': 8,
#   'id': 399,
#   'image_src': None,
#   'info': {'customerType': 'Commercial Office',
#            'floors': '',
#            'geoCity': 'New York',
#            'geoCountry': 'US',
#            'geoState': 'NY',
#            'm2fend': '',
#            'm2fstart': '',
#            'org': '',
#            'satend': '',
#            'satstart': '',
#            'sunend': '',
#            'sunstart': '',
#            'weatherRef': '',
#            'yearBuilt': ''},
#   'name': '97151',
#   'org_id': 5,
#   'point_count': 23,
#   'sq_ft': 140400,
#   'status': 'LIVE',
#   'timezone': 'America/New_York'}]

# %%
df = pd.json_normalize(all_buildings)
df.to_csv('./data/csv/all_buildings.csv', index=False)
df
# Out:
#       id  org_id    name address     sq_ft image_src bms_manufacturer  \
# 0    441       5   88737    None  551143.0      None             None
# 1    140       5   83483    None   21869.0      None             None
# 2    191       5   94414    None  198057.0      None             None
# 3    231       5   89496    None       NaN      None             None
# 4    248       5  116742    None  127000.0      None             None
# ..   ...     ...     ...     ...       ...       ...              ...
# 224  353       5   94413    None  198057.0      None             None
# 225  370       5   95457    None  421316.0      None             None
# 226  383       5   79528    None   75000.0      None             None
# 227  398       5  109188    None  860000.0      None             None
# 228  399       5   97151    None  140400.0      None             None
#
#     bms_product_name bms_version          timezone  ... info.sunend  \
# 0               None        None  America/New_York  ...
# 1               None        None  America/New_York  ...
# 2               None        None  America/New_York  ...       23:00
# 3               None        None  America/New_York  ...
# 4               None        None  America/New_York  ...
# ..               ...         ...               ...  ...         ...
# 224             None        None  America/New_York  ...       23:00
# 225             None        None  America/New_York  ...
# 226             None        None  America/New_York  ...         NaN
# 227             None        None  America/New_York  ...
# 228             None        None  America/New_York  ...
#
#      info.geoCity  info.geoState info.m2fstart info.satstart info.sunstart  \
# 0           Bronx             NY
# 1        New York             NY
# 2          Victor             NY         07:30         07:30         07:30
# 3        New York             NY
# 4        New York             NY
# ..            ...            ...           ...           ...           ...
# 224     Henrietta             NY         07:30         07:30         07:30
# 225      New York             NY
# 226      Purchase       New York      04:00:00           NaN           NaN
# 227      New York             NY
# 228      New York             NY
#
#     info.yearBuilt info.geoCountry info.weatherRef  info.customerType
# 0                               US                        Multifamily
# 1                               US                  Commercial Office
# 2                               US                  Commercial Retail
# 3                               US
# 4                               US                        Multifamily
# ..             ...             ...             ...                ...
# 224                             US                  Commercial Retail
# 225                             US                        Hospitality
# 226           1971              US             NaN  Commercial Office
# 227                             US                  Commercial Office
# 228                             US                  Commercial Office
#
# [229 rows x 27 columns]

# %%
df_98_equipment = pd.json_normalize(client.get_building_equipment(98))
df_98_equipment
# Out:
#        id  building_id              equip_id                suffix  \
# 0   16903           98           Site-Sensor           Site-Sensor
# 1   16904           98          Site-Virtual          Site-Virtual
# 2   16905           98    chilledWaterPlantA    chilledWaterPlantA
# 3   16906           98    chilledWaterPump1A    chilledWaterPump1A
# 4   16907           98    chilledWaterPump1B    chilledWaterPump1B
# 5   16908           98    chilledWaterPump2A    chilledWaterPump2A
# 6   16909           98    chilledWaterPump2B    chilledWaterPump2B
# 7   16910           98    chilledWaterPump3A    chilledWaterPump3A
# 8   16911           98    chilledWaterPump3B    chilledWaterPump3B
# 9   16912           98    chilledWaterPump4A    chilledWaterPump4A
# 10  16913           98             chiller1A             chiller1A
# 11  16914           98             chiller1B             chiller1B
# 12  16915           98             chiller2A             chiller2A
# 13  16916           98             chiller2B             chiller2B
# 14  16917           98             chiller3A             chiller3A
# 15  16918           98             chiller3B             chiller3B
# 16  16919           98  condenserWaterPump1A  condenserWaterPump1A
# 17  16920           98  condenserWaterPump1B  condenserWaterPump1B
# 18  16921           98  condenserWaterPump2A  condenserWaterPump2A
# 19  16922           98  condenserWaterPump2B  condenserWaterPump2B
# 20  16923           98  condenserWaterPump3A  condenserWaterPump3A
# 21  16924           98  condenserWaterPump3B  condenserWaterPump3B
# 22  16925           98  condenserWaterPump4A  condenserWaterPump4A
# 23  16926           98  condenserWaterPump4B  condenserWaterPump4B
# 24  16927           98  condenserWaterPump5B  condenserWaterPump5B
# 25  16928           98  condenserWaterPump6B  condenserWaterPump6B
# 26  16929           98         coolingTower1         coolingTower1
# 27  16930           98        coolingTower1A        coolingTower1A
# 28  16931           98        coolingTower1B        coolingTower1B
# 29  16932           98         coolingTower2         coolingTower2
# 30  16933           98        coolingTower2A        coolingTower2A
# 31  16934           98        coolingTower2B        coolingTower2B
# 32  16935           98         coolingTower3         coolingTower3
# 33  16936           98        coolingTower3A        coolingTower3A
# 34  16937           98        coolingTower3B        coolingTower3B
# 35  16938           98         coolingTower4         coolingTower4
# 36  16939           98             meter6635             meter6635
# 37  16940           98             meter9032             meter9032
#
#         equip_type_name  equip_type_id equip_type_abbr     equip_type_tag  \
# 0          Site Sensors             37            SITE               site
# 1               Virtual             46            VIRT            virtual
# 2   Chilled Water Plant             20            CHWS  chilledWaterPlant
# 3                  Pump             32            PUMP               pump
# 4                  Pump             32            PUMP               pump
# 5                  Pump             32            PUMP               pump
# 6                  Pump             32            PUMP               pump
# 7                  Pump             32            PUMP               pump
# 8                  Pump             32            PUMP               pump
# 9                  Pump             32            PUMP               pump
# 10              Chiller             21              CH            chiller
# 11              Chiller             21              CH            chiller
# 12              Chiller             21              CH            chiller
# 13              Chiller             21              CH            chiller
# 14              Chiller             21              CH            chiller
# 15              Chiller             21              CH            chiller
# 16                 Pump             32            PUMP               pump
# 17                 Pump             32            PUMP               pump
# 18                 Pump             32            PUMP               pump
# 19                 Pump             32            PUMP               pump
# 20                 Pump             32            PUMP               pump
# 21                 Pump             32            PUMP               pump
# 22                 Pump             32            PUMP               pump
# 23                 Pump             32            PUMP               pump
# 24                 Pump             32            PUMP               pump
# 25                 Pump             32            PUMP               pump
# 26        Cooling Tower             23              CT       coolingTower
# 27        Cooling Tower             23              CT       coolingTower
# 28        Cooling Tower             23              CT       coolingTower
# 29        Cooling Tower             23              CT       coolingTower
# 30        Cooling Tower             23              CT       coolingTower
# 31        Cooling Tower             23              CT       coolingTower
# 32        Cooling Tower             23              CT       coolingTower
# 33        Cooling Tower             23              CT       coolingTower
# 34        Cooling Tower             23              CT       coolingTower
# 35        Cooling Tower             23              CT       coolingTower
# 36                Meter             31           METER              meter
# 37                Meter             31           METER              meter
#
#       equip_subtype_name  equip_subtype_id   equip_subtype_tag  flow_order  \
# 0                   None               NaN                None           5
# 1                   None               NaN                None           5
# 2                   None               NaN                None           1
# 3     Chilled Water Pump              20.0    chilledWaterPump           1
# 4     Chilled Water Pump              20.0    chilledWaterPump           1
# 5     Chilled Water Pump              20.0    chilledWaterPump           1
# 6     Chilled Water Pump              20.0    chilledWaterPump           1
# 7     Chilled Water Pump              20.0    chilledWaterPump           1
# 8     Chilled Water Pump              20.0    chilledWaterPump           1
# 9     Chilled Water Pump              20.0    chilledWaterPump           1
# 10    Absorption Chiller               6.0   absorptionChiller           1
# 11    Absorption Chiller               6.0   absorptionChiller           1
# 12    Absorption Chiller               6.0   absorptionChiller           1
# 13    Absorption Chiller               6.0   absorptionChiller           1
# 14    Absorption Chiller               6.0   absorptionChiller           1
# 15    Absorption Chiller               6.0   absorptionChiller           1
# 16  Condenser Water Pump              26.0  condenserWaterPump           1
# 17  Condenser Water Pump              26.0  condenserWaterPump           1
# 18  Condenser Water Pump              26.0  condenserWaterPump           1
# 19  Condenser Water Pump              26.0  condenserWaterPump           1
# 20  Condenser Water Pump              26.0  condenserWaterPump           1
# 21  Condenser Water Pump              26.0  condenserWaterPump           1
# 22  Condenser Water Pump              26.0  condenserWaterPump           1
# 23  Condenser Water Pump              26.0  condenserWaterPump           1
# 24  Condenser Water Pump              26.0  condenserWaterPump           1
# 25  Condenser Water Pump              26.0  condenserWaterPump           1
# 26                  None               NaN                None           1
# 27                  None               NaN                None           1
# 28                  None               NaN                None           1
# 29                  None               NaN                None           1
# 30                  None               NaN                None           1
# 31                  None               NaN                None           1
# 32                  None               NaN                None           1
# 33                  None               NaN                None           1
# 34                  None               NaN                None           1
# 35                  None               NaN                None           1
# 36      Electrical Meter              16.0           elecMeter           5
# 37      Electrical Meter              16.0           elecMeter           5
#
#    floor_num_physical floor_num_served area_served_desc  \
# 0                None             None
# 1                None             None
# 2                None             None
# 3                None             None
# 4                None             None
# 5                None             None
# 6                None             None
# 7                None             None
# 8                None             None
# 9                None             None
# 10               None             None
# 11               None             None
# 12               None             None
# 13               None             None
# 14               None             None
# 15               None             None
# 16               None             None
# 17               None             None
# 18               None             None
# 19               None             None
# 20               None             None
# 21               None             None
# 22               None             None
# 23               None             None
# 24               None             None
# 25               None             None
# 26               None             None
# 27               None             None
# 28               None             None
# 29               None             None
# 30               None             None
# 31               None             None
# 32               None             None
# 33               None             None
# 34               None             None
# 35               None             None
# 36               None             None
# 37               None             None
#
#                    equip_dis parent_equip child_equip  \
# 0                                      []          []
# 1                                      []          []
# 2     Electric Plant  - 40HP           []          []
# 3     Electric Plant  - 75HP           []          []
# 4        Steam Plant - 300HP           []          []
# 5     Electric Plant  - 75HP           []          []
# 6        Steam Plant - 300HP           []          []
# 7     Electric Plant  - 75HP           []          []
# 8        Steam Plant - 300HP           []          []
# 9     Electric Plant  - 75HP           []          []
# 10  Electric Plant - 875 Ton           []          []
# 11    Steam Plant - 3000 Ton           []          []
# 12  Electric Plant - 875 Ton           []          []
# 13    Steam Plant - 3000 Ton           []          []
# 14  Electric Plant - 875 Ton           []          []
# 15    Steam Plant - 3000 Ton           []          []
# 16    Electric Plant - 100HP           []          []
# 17       Steam Plant - 200HP           []          []
# 18    Electric Plant - 100HP           []          []
# 19       Steam Plant - 200HP           []          []
# 20    Electric Plant - 100HP           []          []
# 21       Steam Plant - 200HP           []          []
# 22    Electric Plant - 100HP           []          []
# 23       Steam Plant - 200HP           []          []
# 24       Steam Plant - 200HP           []          []
# 25       Steam Plant - 200HP           []          []
# 26    Electric Plant  - 40HP           []          []
# 27       Steam Plant - 125HP           []          []
# 28       Steam Plant - 125HP           []          []
# 29    Electric Plant  - 40HP           []          []
# 30       Steam Plant - 125HP           []          []
# 31       Steam Plant - 125HP           []          []
# 32    Electric Plant  - 40HP           []          []
# 33       Steam Plant - 125HP           []          []
# 34       Steam Plant - 125HP           []          []
# 35    Electric Plant  - 40HP           []          []
# 36               6635 - 1ENT           []          []
# 37               9032 - 1ENT           []          []
#
#                                                points  \
# 0   [{'id': 190806, 'building_id': 98, 'last_updat...
# 1   [{'id': 190862, 'building_id': 98, 'last_updat...
# 2   [{'id': 190882, 'building_id': 98, 'last_updat...
# 3   [{'id': 190883, 'building_id': 98, 'last_updat...
# 4   [{'id': 190884, 'building_id': 98, 'last_updat...
# 5   [{'id': 190885, 'building_id': 98, 'last_updat...
# 6   [{'id': 190886, 'building_id': 98, 'last_updat...
# 7   [{'id': 190887, 'building_id': 98, 'last_updat...
# 8   [{'id': 190888, 'building_id': 98, 'last_updat...
# 9   [{'id': 190890, 'building_id': 98, 'last_updat...
# 10  [{'id': 190892, 'building_id': 98, 'last_updat...
# 11  [{'id': 190894, 'building_id': 98, 'last_updat...
# 12  [{'id': 190897, 'building_id': 98, 'last_updat...
# 13  [{'id': 190904, 'building_id': 98, 'last_updat...
# 14  [{'id': 190905, 'building_id': 98, 'last_updat...
# 15  [{'id': 190908, 'building_id': 98, 'last_updat...
# 16  [{'id': 190913, 'building_id': 98, 'last_updat...
# 17  [{'id': 190914, 'building_id': 98, 'last_updat...
# 18  [{'id': 190915, 'building_id': 98, 'last_updat...
# 19  [{'id': 190916, 'building_id': 98, 'last_updat...
# 20  [{'id': 190917, 'building_id': 98, 'last_updat...
# 21  [{'id': 190918, 'building_id': 98, 'last_updat...
# 22  [{'id': 190919, 'building_id': 98, 'last_updat...
# 23  [{'id': 190920, 'building_id': 98, 'last_updat...
# 24  [{'id': 190921, 'building_id': 98, 'last_updat...
# 25  [{'id': 190922, 'building_id': 98, 'last_updat...
# 26  [{'id': 190923, 'building_id': 98, 'last_updat...
# 27  [{'id': 190924, 'building_id': 98, 'last_updat...
# 28  [{'id': 190925, 'building_id': 98, 'last_updat...
# 29  [{'id': 190926, 'building_id': 98, 'last_updat...
# 30  [{'id': 190927, 'building_id': 98, 'last_updat...
# 31  [{'id': 190928, 'building_id': 98, 'last_updat...
# 32  [{'id': 190929, 'building_id': 98, 'last_updat...
# 33  [{'id': 190930, 'building_id': 98, 'last_updat...
# 34  [{'id': 190931, 'building_id': 98, 'last_updat...
# 35  [{'id': 190932, 'building_id': 98, 'last_updat...
# 36  [{'id': 190933, 'building_id': 98, 'last_updat...
# 37  [{'id': 190935, 'building_id': 98, 'last_updat...
#
#                                                 tags
# 0                                             [site]
# 1                                                 []
# 2                          [hvac, chilledWaterPlant]
# 3                     [pump, hvac, chilledWaterPump]
# 4                     [pump, hvac, chilledWaterPump]
# 5                     [pump, hvac, chilledWaterPump]
# 6                     [pump, hvac, chilledWaterPump]
# 7                     [pump, hvac, chilledWaterPump]
# 8                     [pump, hvac, chilledWaterPump]
# 9                     [pump, hvac, chilledWaterPump]
# 10  [chiller, hvac, waterCooling, absorptionChiller]
# 11  [chiller, hvac, waterCooling, absorptionChiller]
# 12  [chiller, hvac, waterCooling, absorptionChiller]
# 13  [chiller, hvac, waterCooling, absorptionChiller]
# 14  [chiller, hvac, waterCooling, absorptionChiller]
# 15  [chiller, hvac, waterCooling, absorptionChiller]
# 16                  [pump, hvac, condenserWaterPump]
# 17                  [pump, hvac, condenserWaterPump]
# 18                  [pump, hvac, condenserWaterPump]
# 19                  [pump, hvac, condenserWaterPump]
# 20                  [pump, hvac, condenserWaterPump]
# 21                  [pump, hvac, condenserWaterPump]
# 22                  [pump, hvac, condenserWaterPump]
# 23                  [pump, hvac, condenserWaterPump]
# 24                  [pump, hvac, condenserWaterPump]
# 25                  [pump, hvac, condenserWaterPump]
# 26                              [coolingTower, hvac]
# 27                              [coolingTower, hvac]
# 28                              [coolingTower, hvac]
# 29                              [coolingTower, hvac]
# 30                              [coolingTower, hvac]
# 31                              [coolingTower, hvac]
# 32                              [coolingTower, hvac]
# 33                              [coolingTower, hvac]
# 34                              [coolingTower, hvac]
# 35                              [coolingTower, hvac]
# 36                                [meter, elecMeter]
# 37                                [meter, elecMeter]

# %%
df_98_points = pd.json_normalize(client.get('/buildings/98/points').json())
df_98_points
# Out:
#          id  building_id  last_updated  first_updated device network_device  \
# 0    190864           98  1.512147e+12   1.477930e+12                  None
# 1    190816           98  1.535558e+12   1.477930e+12                  None
# 2    190856           98  1.535558e+12   1.477930e+12                  None
# 3    190892           98  1.535558e+12   1.477930e+12                  None
# 4    190886           98  1.535558e+12   1.477930e+12                  None
# ..      ...          ...           ...            ...    ...            ...
# 127  190810           98  1.535558e+12   1.477930e+12                  None
# 128  190865           98  1.512147e+12   1.477930e+12                  None
# 129  190908           98  1.506700e+12   1.496333e+12                  None
# 130  190862           98  1.512147e+12   1.477930e+12                  None
# 131  190882           98  1.535558e+12   1.477930e+12                  None
#
#     objectId name                                     description   units  \
# 0                                Elec Plant Tons to Building Tons
# 1                                                      Adjusted.7
# 2                                                     Adjusted.40
# 3                                                   RM1 Tons Tons    tons
# 4                                Steam Plant CHWP 2 Status On/Off  On/Off
# ..       ...  ...                                             ...     ...
# 127                                                    Adjusted.1
# 128                                                   Adjusted.47
# 129                                                  17DA3 Status  On/Off
# 130                             Elec Plant Free Cooling Tons Tons
# 131                Elec Plant Free Cooling Enabled Enable/Disable  On/Off
#
#     tagged_units  raw_unit_id   value        type  point_type_id  \
# 0           None           23     0.0     Virtual            434
# 1           None           23     0.0     Virtual            434
# 2           None           23     1.0     Virtual            434
# 3           None           33     2.0  Real Power            221
# 4           None           20     0.0      Status            121
# ..           ...          ...     ...         ...            ...
# 127         None           23     0.0     Virtual            434
# 128         None           23     0.0     Virtual            434
# 129         None           20     0.0      Status            121
# 130         None           23  232.66     Virtual            434
# 131         None           20     0.0     Command            166
#
#      measurement_id                   datasource_hash  \
# 0                18  7adedac7e1358117711a3ed1d54844e5
# 1                18  f67037047d166079ebb2d74de4ea155f
# 2                18  4745a314e7a883240c6ea6831914cbbc
# 3                13  2d3dc7711f6c118098dab00269f27fbd
# 4                11  4bcea2d92378ea4dac89ba45adec8e75
# ..              ...                               ...
# 127              18  c69619dbbc6e00e628bc93ce7dadd87a
# 128              18  7cae2ce2dfb8f92a5a0c0f3fe1a39729
# 129              11  88f354dd9101678ffc78748d2659d7ae
# 130              18  d660ff511c58e1853f3e5024d2fa14d1
# 131              11  af17abd13c889e76b98ab5cdc994a47c
#
#                                                  topic state_text  equip_id
# 0    nyserda+0000068855+Site-Virtual+Elec Plant Ton...       None     16904
# 1           nyserda+0000068855+Site-Virtual+Adjusted.7       None     16904
# 2          nyserda+0000068855+Site-Virtual+Adjusted.40       None     16904
# 3           nyserda+0000068855+chiller1A+RM1 Tons Tons       None     16913
# 4    nyserda+0000068855+chilledWaterPump2B+Steam Pl...       None     16909
# ..                                                 ...        ...       ...
# 127         nyserda+0000068855+Site-Virtual+Adjusted.1       None     16904
# 128        nyserda+0000068855+Site-Virtual+Adjusted.47       None     16904
# 129          nyserda+0000068855+chiller3B+17DA3 Status       None     16918
# 130  nyserda+0000068855+Site-Virtual+Elec Plant Fre...       None     16904
# 131  nyserda+0000068855+chilledWaterPlantA+Elec Pla...       None     16905
#
# [132 rows x 20 columns]

# %%
df_equip_types = pd.json_normalize(client.get_equipment_types())
df_equip_types
# Out:
#     id             tag_name                      name_long name_abbr  active  \
# 0   12                  ahu              Air Handling Unit       AHU    True
# 1   19               boiler                         Boiler       BLR    True
# 2   20    chilledWaterPlant            Chilled Water Plant      CHWS    True
# 3   21              chiller                        Chiller        CH    True
# 4   22            condenser                      Condenser      COND    True
# 5   23         coolingTower                  Cooling Tower        CT    True
# 6   25           evaporator                     Evaporator      EVAP    True
# 7   26                  fan                            Fan       FAN    True
# 8    9                  fcu                  Fan Coil Unit       FCU    True
# 9   28        heatExchanger                 Heat Exchanger        HX    True
# 10  29             heatPump                      Heat Pump        HP    True
# 11  30        hotWaterPlant                Hot Water Plant       HWS    True
# 12  31                meter                          Meter     METER    True
# 13  32                 pump                           Pump      PUMP    True
# 14  33                 tank                           Tank      TANK    True
# 15  34             unitVent                Unit Ventilator        UV    True
# 16   7                  vav            Variable Air Volume       VAV    True
# 17  36                  vrf      Variable Refrigerant Flow       VRF    True
# 18  39           ductHeater                    Duct Heater      DUCT    True
# 19  57            waterLoop                     Water Loop     WLOOP    True
# 20  47                 crac  Computer Room Air Conditioner      CRAC    True
# 21  46              virtual                        Virtual      VIRT    True
# 22  40         radiantEquip                 Radiant System   RADIANT    True
# 23  52                shade                          Shade     SHADE    True
# 24  37                 site                   Site Sensors      SITE    True
# 25  24                panel               Electrical Panel      ELEC    True
# 26  55         leakDetector                  Leak Detector      LEAK    True
# 27  38             untagged                       Untagged      NONE    True
# 28  48                cogen             Cogeneration Plant     COGEN    True
# 29  50            dryCooler                     Dry Cooler    COOLER    True
# 30  51           humidifier                     Humidifier       HUM    True
# 31  42             lighting                Lighting System     LIGHT    True
# 32  41             elevator                       Elevator      ELEV    True
# 33  54  fireSafetyEquipment          Fire Safety Equipment  FIRESFTY    True
# 34  53    securityEquipment             Security Equipment  SECURITY    True
# 35  44                  cav            Constant Air Volume       CAV    True
# 36  49             airDryer                      Air Dryer     DRYER    True
# 37  45              battery                        Battery      BATT    True
# 38  43             fumeHood                      Fume Hood      FUME    True
#
#     flow_order       critical_point_types  \
# 0            2    [79, 85, 103, 159, 160]
# 1            1    [88, 131, 92, 167, 121]
# 2            1    [89, 132, 93, 116, 108]
# 3            1    [89, 132, 93, 167, 121]
# 4            1                      [121]
# 5            1         [89, 132, 93, 116]
# 6            1                      [121]
# 7            4            [166, 121, 158]
# 8            3    [79, 77, 122, 159, 160]
# 9            1              [88, 92, 183]
# 10           1         [79, 77, 122, 121]
# 11           1    [88, 131, 92, 115, 107]
# 12           5  [116, 115, 176, 178, 179]
# 13           1            [166, 121, 158]
# 14           1                   [87, 91]
# 15           3   [79, 148, 150, 166, 121]
# 16           3    [112, 79, 77, 122, 159]
# 17           3             [77, 122, 121]
# 18           5                         []
# 19           1                         []
# 20           2                         []
# 21           5                         []
# 22           3                         []
# 23           5                         []
# 24           5                         []
# 25           1                         []
# 26           5                         []
# 27          10                         []
# 28           1                         []
# 29           5                         []
# 30           5                         []
# 31           5                         []
# 32           4                         []
# 33           5                         []
# 34           5                         []
# 35          -1                         []
# 36           5                         []
# 37           5                         []
# 38          -1                         []
#
#                                             sub_types  \
# 0   [{'id': 1, 'equipment_type_id': 12, 'tag_name'...
# 1   [{'id': 4, 'equipment_type_id': 19, 'tag_name'...
# 2                                                  []
# 3   [{'id': 7, 'equipment_type_id': 21, 'tag_name'...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7   [{'id': 12, 'equipment_type_id': 26, 'tag_name...
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11  [{'id': 43, 'equipment_type_id': 30, 'tag_name...
# 12  [{'id': 16, 'equipment_type_id': 31, 'tag_name...
# 13  [{'id': 20, 'equipment_type_id': 32, 'tag_name...
# 14                                                 []
# 15                                                 []
# 16  [{'id': 32, 'equipment_type_id': 7, 'tag_name'...
# 17                                                 []
# 18  [{'id': 36, 'equipment_type_id': 39, 'tag_name...
# 19  [{'id': 45, 'equipment_type_id': 57, 'tag_name...
# 20                                                 []
# 21                                                 []
# 22  [{'id': 29, 'equipment_type_id': 40, 'tag_name...
# 23                                                 []
# 24  [{'id': 35, 'equipment_type_id': 37, 'tag_name...
# 25  [{'id': 10, 'equipment_type_id': 24, 'tag_name...
# 26                                                 []
# 27                                                 []
# 28                                                 []
# 29                                                 []
# 30                                                 []
# 31  [{'id': 34, 'equipment_type_id': 42, 'tag_name...
# 32                                                 []
# 33  [{'id': 41, 'equipment_type_id': 54, 'tag_name...
# 34                                                 []
# 35                                                 []
# 36                                                 []
# 37                                                 []
# 38                                                 []
#
#                                       tags
# 0                              [hvac, ahu]
# 1                           [hvac, boiler]
# 2                [hvac, chilledWaterPlant]
# 3                          [hvac, chiller]
# 4                        [hvac, condenser]
# 5                     [hvac, coolingTower]
# 6                       [hvac, evaporator]
# 7                              [hvac, fan]
# 8                              [hvac, fcu]
# 9                    [hvac, heatExchanger]
# 10  [hvac, dxHeating, dxCooling, heatPump]
# 11                   [hvac, hotWaterPlant]
# 12                                 [meter]
# 13                            [hvac, pump]
# 14                                  [tank]
# 15                        [hvac, unitVent]
# 16                             [hvac, vav]
# 17                             [hvac, vrf]
# 18                      [hvac, ductHeater]
# 19                                      []
# 20                            [crac, hvac]
# 21                                      []
# 22                    [hvac, radiantEquip]
# 23                                      []
# 24                                  [site]
# 25                                 [panel]
# 26                                      []
# 27                                      []
# 28                                      []
# 29                                      []
# 30                                      []
# 31                              [lighting]
# 32                              [elevator]
# 33                                      []
# 34                                      []
# 35                             [hvac, cav]
# 36                                      []
# 37                               [battery]
# 38                        [hvac, fumeHood]

# %%
from datetime import datetime, timezone, timedelta
import pytz
from onboard.client.models import TimeseriesQuery, PointData
from onboard.client.dataframes import points_df_from_streaming_timeseries
from datetime import datetime, timezone, timedelta
import pytz
from onboard.client.models import TimeseriesQuery, PointData, PointSelector
from onboard.client.dataframes import points_df_from_streaming_timeseries

# %% [markdown]
# >>> # Get time series data for the sensors you would like to query
# >>> timeseries_query = TimeseriesQuery(point_ids = selection['points'], start = start, end = end)
# >>> sensor_data = points_df_from_streaming_timeseries(client.stream_point_timeseries(timeseries_query))
# >>> sensor_data
#                          timestamp 289575 289701
# 0      2022-01-04T19:34:11.741000Z   68.0   None
# 1      2022-01-04T19:34:19.143000Z   None   62.0
# 2      2022-01-04T19:35:12.133000Z   68.0   None

# %%
query = PointSelector()
query.point_types = ['Real Power', 'Zone Temperature']
query.buildings = ['68855']
selection = client.select_points(query)
timeseries_query = TimeseriesQuery(point_ids = ['311176'], start = '2017-08-29T15:55:00Z', end = '2020-08-29T15:55:00Z')
sensor_data = points_df_from_streaming_timeseries(client.stream_point_timeseries(timeseries_query))
sensor_data
# Out:
#                   timestamp     311176
# 0      2019-01-19T17:00:00Z  23.810650
# 1      2019-01-19T17:15:00Z  23.810650
# 2      2019-01-19T17:30:00Z  23.810650
# 3      2019-01-19T17:45:00Z  23.748148
# 4      2019-01-19T18:00:00Z  23.748148
# ...                     ...        ...
# 38801  2019-06-14T03:45:00Z  20.623148
# 38802  2019-06-14T03:50:00Z  20.623148
# 38803  2019-06-14T03:55:00Z  20.623148
# 38804  2019-06-14T04:00:00Z  20.623148
# 38805  2019-06-14T04:05:00Z  20.623148
#
# [38806 rows x 2 columns]

# %%
sensor_data
# Out:
#                   timestamp 190856
# 0      2018-06-03T12:05:00Z   None
# 1      2018-06-03T12:10:00Z   None
# 2      2018-06-03T12:15:00Z   None
# 3      2018-06-03T12:20:00Z   None
# 4      2018-06-03T12:25:00Z   None
# ...                     ...    ...
# 24866  2018-08-29T15:35:00Z   None
# 24867  2018-08-29T15:40:00Z   None
# 24868  2018-08-29T15:45:00Z   None
# 24869  2018-08-29T15:50:00Z   None
# 24870  2018-08-29T15:55:00Z   None
#
# [24871 rows x 2 columns]
