# %%
# Get Onboard Client provided by RTEMHackathon
import json

from onboard.client import RtemClient
# Access API Key securely using config.ini file
import configparser
from pprint import pprint
import pandas as pd

# %%
# Load API Key using configparser
config = configparser.ConfigParser()
config.read('config.ini')
api_key = config['DEFAULT']['API_KEY']
# Initialise Onboard Client
client = RtemClient(api_key=api_key)

# %%
point_types = client.get_all_point_types()
point_types
# Out:
# [{'id': 124,
#   'tag_name': 'Occupied Heating Setpoint',
#   'active': True,
#   'measurement_id': 1,
#   'tag_set_ids': [15, 2, 4, 62, 51, 55],
#   'tags': ['air', 'sp', 'temp', 'zone', 'heating', 'occ'],
#   'default_unit_id': None},
#  {'id': 118,
#   'tag_name': 'Outside Air Carbon Dioxide',
#   'active': True,
#   'measurement_id': 6,
#   'tag_set_ids': [15, 8, 1, 24],
#   'tags': ['air', 'co2', 'sensor', 'outside'],
#   'default_unit_id': None},
#  {'id': 130,
#   'tag_name': 'Return Air Temperature Setpoint',
#   'active': True,
#   'measurement_id': 1,
#   'tag_set_ids': [15, 2, 4, 63],
#   'tags': ['air', 'sp', 'temp', 'return'],
#   'default_unit_id': None},
#  {'id': 84,
#   'tag_name': 'Dual-Temp Coil Discharge Air Temperature',
#   'active': True,
#   'measurement_id': 1,
#   'tag_set_ids': [15, 36, 47, 1, 4, 250],
#   'tags': ['air', 'discharge', 'dualTemp', 'sensor', 'temp', 'coil'],
#   'default_unit_id': None},
#  {'id': 81,
# ...

# %%
df = pd.json_normalize(point_types)
df
# Out:
#       id                                  tag_name  active  measurement_id  \
# 0    124                 Occupied Heating Setpoint    True               1
# 1    118                Outside Air Carbon Dioxide    True               6
# 2    130           Return Air Temperature Setpoint    True               1
# 3     84  Dual-Temp Coil Discharge Air Temperature    True               1
# 4     81     Reheat Coil Discharge Air Temperature    True               1
# ..   ...                                       ...     ...             ...
# 640  747        Heating Coil Valve Position Sensor    True               7
# 641  748        Cooling Coil Valve Position Sensor    True               7
# 642  749                     Supply Water Pressure    True               3
# 643  750                     Return Water Pressure    True               3
# 644   46                                  untagged    True              18
#
# ...

# %%
measurement_types = pd.json_normalize(client.get_all_measurements())
measurement_types
# Out:
#     id               name  default_unit_id  units_convertible  \
# 0   10          Occupancy              NaN              False
# 1   57      Dimensionless              NaN              False
# 2   11             On/Off              NaN              False
# 3   17        Motor Speed              NaN              False
# 4   31             Torque              NaN              False
# 5   39           Gas Flow              NaN              False
# 6    7           Position              NaN              False
# 7   12             Enable             21.0               True
# 8   15         Open/Close             19.0               True
# 9   26              State             31.0               True
# 10  36           Schedule             31.0               True
# 11  23         Percentage              NaN              False
# 12  20     Reactive Power             25.0               True
# 13  27              Floor             32.0               True
# ...

# %%
equipment_types = pd.json_normalize(client.get_all_equipment())
equipment_types
# Out:
#          id  building_id            equip_id suffix equip_type_name  \
# 0     28797          441            boiler-1      1          Boiler
# 1     28798          441            boiler-2      2          Boiler
# 2     28799          441            boiler-3      3          Boiler
# 3     28800          441            boiler-4      4          Boiler
# 4     28801          441            boiler-5      5          Boiler
# ...     ...          ...                 ...    ...             ...
# 6076  32354          399    chilledWaterPump   None            Pump
# 6077  32355          399  chilledWaterPump-4      4            Pump
# 6078  32356          399           condenser   None       Condenser
# 6079  32357          399  condenserWaterPump   None            Pump
# 6080  32358          399      elecMeter-site   site           Meter
#
#       equip_type_id equip_type_abbr equip_type_tag    equip_subtype_name  \
# 0                19             BLR         boiler                  None
# ...

# %%
b_99 = pd.json_normalize(client.get_building_equipment(99))
b_99
# Out:
#         id  building_id            equip_id       suffix    equip_type_name  \
# 0    17057           99        rtu-csa-58-1     csa-58-1  Air Handling Unit
# 1    17058           99        rtu-csa-58-2     csa-58-2  Air Handling Unit
# 2    17059           99      rtu-hov-4-58-1   hov-4-58-1  Air Handling Unit
# 3    16964           99  condenser-acc-29-5     acc-29-5          Condenser
# 4    16965           99  condenser-acc-57-1     acc-57-1          Condenser
# ..     ...          ...                 ...          ...                ...
# 121  31771           99       panel-hpl-2-1      hpl-2-1   Electrical Panel
# 122  31772           99   panel-hpl-c-56-58  hpl-c-56-58   Electrical Panel
# 123  31773           99      panel-hpl-c-71     hpl-c-71   Electrical Panel
# 124  31774           99   panel-hpl-c-79-81  hpl-c-79-81   Electrical Panel
# 125  31775           99     panel-hpl-c1-70    hpl-c1-70   Electrical Panel
#
# ...

# %%
b_98 = pd.json_normalize(client.get_building_equipment(98))
b_98
# Out:
#        id  building_id              equip_id                suffix  \
# 0   16903           98           Site-Sensor           Site-Sensor
# 1   16904           98          Site-Virtual          Site-Virtual
# 2   16905           98    chilledWaterPlantA    chilledWaterPlantA
# 3   16906           98    chilledWaterPump1A    chilledWaterPump1A
# 4   16907           98    chilledWaterPump1B    chilledWaterPump1B
# 5   16908           98    chilledWaterPump2A    chilledWaterPump2A
# 6   16909           98    chilledWaterPump2B    chilledWaterPump2B
# 7   16910           98    chilledWaterPump3A    chilledWaterPump3A
# 8   16911           98    chilledWaterPump3B    chilledWaterPump3B
# 9   16912           98    chilledWaterPump4A    chilledWaterPump4A
# 10  16913           98             chiller1A             chiller1A
# 11  16914           98             chiller1B             chiller1B
# 12  16915           98             chiller2A             chiller2A
# ...

# %%
b_134 = pd.json_normalize(client.get_building_equipment(134))
b_134
# Out:
#         id  building_id           equip_id             suffix  \
# 0    17929          134               ac-2               ac-2
# 1    17930          134          ac-blower          ac-blower
# 2    17931          134       ac-condenser       ac-condenser
# 3    17932          134           ahu-left           ahu-left
# 4    17933          134          ahu-right          ahu-right
# ..     ...          ...                ...                ...
# 124  18053          134          meter-tk3          meter-tk3
# 125  18054          134          meter-tk4          meter-tk4
# 126  18055          134  meter-wallOutlets  meter-wallOutlets
# 127  18056          134               uh-1               uh-1
# 128  18057          134               uh-2               uh-2
#
#        equip_type_name  equip_type_id equip_type_abbr equip_type_tag  \
# 0    Air Handling Unit             12             AHU            ahu
# 1    Air Handling Unit             12             AHU            ahu
# ...

# %%
pd.json_normalize(client.get_all_buildings())
# Out:
#       id  org_id    name address     sq_ft image_src bms_manufacturer  \
# 0    441       5   88737    None  551143.0      None             None
# 1    140       5   83483    None   21869.0      None             None
# 2    191       5   94414    None  198057.0      None             None
# 3    231       5   89496    None       NaN      None             None
# 4    248       5  116742    None  127000.0      None             None
# ..   ...     ...     ...     ...       ...       ...              ...
# 224  353       5   94413    None  198057.0      None             None
# 225  370       5   95457    None  421316.0      None             None
# 226  383       5   79528    None   75000.0      None             None
# 227  398       5  109188    None  860000.0      None             None
# 228  399       5   97151    None  140400.0      None             None
#
#     bms_product_name bms_version          timezone  ... info.sunend  \
# 0               None        None  America/New_York  ...
# ...

# %%
pd.json_normalize(client.get_building_equipment(181))
# Out:
#        id  building_id        equip_id          suffix equip_type_name  \
# 0   18622          181     Site-Sensor     Site-Sensor    Site Sensors
# 1   18623          181     battery-PHA     battery-PHA         Battery
# 2   18624          181     battery-PHB     battery-PHB         Battery
# 3   18625          181     battery-PHC     battery-PHC         Battery
# 4   18626          181     battery-PHD     battery-PHD         Battery
# 5   18627          181     battery-PHE     battery-PHE         Battery
# 6   18628          181  battery-office  battery-office         Battery
# 7   18629          181      battery10A      battery10A         Battery
# 8   18630          181      battery10E      battery10E         Battery
# 9   18631          181      battery10M      battery10M         Battery
# 10  18632          181      battery10N      battery10N         Battery
# 11  18633          181      battery11C      battery11C         Battery
# ...
